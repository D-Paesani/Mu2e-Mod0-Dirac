# %%
import numpy as np
import matplotlib
matplotlib.use('agg')
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
# import tensorflow as tf
# import keras
from os import path
import ROOT
import genprova
# print(tf.test.gpu_device_name())
# Ndataset, nsplit = int(1e4), .3
# %matplotlib inline
# Out:
# Welcome to JupyROOT 6.26/06

# %%
c = ROOT.TCanvas("c","c",400,300)
c.Draw()
genprova.spline.SetLineColor(ROOT.kBlue)
genprova.spline.Draw("L")

# %%
plt.figure(figsize=(15, 4))
for i in (range(50)):
    ww, _, _ = genprova.get1wave()
    plt.scatter(genprova.twave, ww, s=0.2)

nn = 10
fig, ax = plt.subplots(10, figsize=(15,10*2.5))
for ii in range(nn): 
    ww, _, tw = genprova.get1wave()
    ax[ii].plot(genprova.twave, ww, '.k')
    ax[ii].plot(genprova.twave, tw, '--r')
